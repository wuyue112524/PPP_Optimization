# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from Wrapper.W_momen_factor_create import *
from Wrapper.W_pre_factor_data_mani import *
from Wrapper.W_pre_opt_data_mani import wrapper_df_preparation
from Wrapper.W_pre_opt_obj_func import (wrapper_objective_compo_creation,
                                               wrapper_objective_func)
import scipy.optimize as opt
from Wrapper.Moduel.M_FactorCreator import FactorsConstruction
from Wrapper.W_pre_opt_factor_standardize import wrapper_standardize_factor
from Wrapper.Moduel.M_SupportFunction import (weight_prediction,get_new_factor_value)
from Wrapper.W_opt_ppp import PPP_optimize
from Wrapper.Moduel.M_BackTest import BackTest
from Wrapper.Moduel.M_BenchmarkBacktest import Benchmark
from Wrapper.Moduel.M_PerforEvalu import ModelFreeEvaluation
def plot_multiple_series(dataframe,date_name, colname_list):
    plt.figure(figsize = (20,10))
    for colname in colname_list:
        plt.plot(dataframe[date_name],dataframe[colname])
    plt.legend()

# %%
price_file = "Data/Price.csv"
price_df, ticker_list = wrapper_import_data(price_file)
return_df, factor_df = wrapper_return_calculation(price_df, 
                           ticker_list,
                           look_back_list=[12],skip=0,
                           target_name='price',frequency='BM')
factor_df, return_df  = wrapper_factor_return_output(return_df,factor_df)
factor_list = ["momentum_12"]
reshape_dic = wrapper_df_preparation(return_df,factor_df,factor_list)
factor_dic = reshape_dic["factor_dic"]
ret_mat = reshape_dic["ret_mat"]
factor_dic.update({'ret_mat':ret_mat})
ret_mat_test = pd.DataFrame(ret_mat)
ret_mat_test = ret_mat_test.shift(1)
ret_mat_test = np.array(ret_mat_test)
date_df = return_df[return_df['ticker']=='AEP']
date = date_df['date']
general_dic = {'ticker_list':ticker_list,'ret_mat_test':ret_mat_test,'factor_list':factor_list,'date':date}
factor_dic = wrapper_standardize_factor(ticker_list,factor_dic)
data_dict ={'strategy_specific_data':factor_dic,'general_data':general_dic}

# %%
def func(x):
    final_weight = PPP_optimize(x,ticker_list=ticker_list,factor_list=factor_list)
    return final_weight

# %%
back_obj = BackTest(data_dict,func)

# %%
rp_storage, weight_storage,date_storage = back_obj.historical_backtest(est_length = 100,start_index=101,end_index=200,update=1,fixed=True)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.247777
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248303
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.247914
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.247831
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248335
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248443
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248645
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248216
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248075
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248123
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248250
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.247749
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248082
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248291
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248823
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249049
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249346
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249222
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249574
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249358
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248946
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249243
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249398
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249245
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249047
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248752
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248703
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248855
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248779
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248883
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248921
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248948
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249019
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.248965
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249390
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249416
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249591
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249713
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249822
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249783
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249721
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249725
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249767
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249748
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249657
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249676
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249608
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249846
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249550
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249587
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249790
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249924
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249957
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249871
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249951
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249978
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249932
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249794
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249850
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249922
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249889
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249843
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249911
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249889
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249814
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249747
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249724
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249912
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249989
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249995
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.250000
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249999
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249999
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249924
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249940
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249854
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249991
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.250000
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249998
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249999
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249997
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249969
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249999
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249966
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249996
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249876
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249745
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249811
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249797
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249804
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249905
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249945
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249806
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249737
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249485
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249495
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249185
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249120
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249139
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.249515
#          Iterations: 17
#          Function evaluations: 34

# %%
obj = Benchmark(rp_storage,date_storage)

# %%
final_return_df = obj.equalweight(data= data_dict ,asset_num = 5, update=1,fixed=True)

# %%
obj_1 = ModelFreeEvaluation(final_return_df['strategy_return'],final_return_df['date'])
obj_2 = ModelFreeEvaluation(final_return_df['benchmark_return'],final_return_df['date'])

# %%
obj_1.sharpe_ratio(annul_freq=12,rf=0.0016)
# Out:
# 0.7231652318162163

# %%
obj_2.sharpe_ratio(annul_freq=12,rf=0.0016)
# Out:
# 0.7173352208160747

# %%
cum_ret_1 = obj_1.cum_ret_calculation()
cum_ret_2 = obj_2.cum_ret_calculation()

# %%
dd1, mdd1, ddd1 = obj_1.drawdown_calculation()
dd2, mdd2, ddd2 = obj_2.drawdown_calculation()

# %%
final_return_df['cum_ret_1']=cum_ret_1
final_return_df['cum_ret_2']=cum_ret_2
final_return_df['dd1'] = dd1
final_return_df['dd2'] = dd2

# %%
plot_multiple_series(final_return_df,'date',['strategy_return','benchmark_return'])
# Out:
# C:\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plot_multiple_series(final_return_df,'date',['cum_ret_1','cum_ret_2'])

# %%
plot_multiple_series(final_return_df,'date',['dd1','dd2'])

# %%
mdd1
# Out:
# -0.16501962441677764

# %%
mdd2
# Out:
# -0.1614199500250234

# %%
ddd1
# Out:
# 15.0

# %%
ddd2
# Out:
# 13.0
